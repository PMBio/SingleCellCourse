# %% [markdown]
# # Analysis of Visium data
#
# Resources:
# * [Public Visium datasets from 10x](https://www.10xgenomics.com/resources/datasets?query=&page=1&configure%5Bfacets%5D%5B0%5D=chemistryVersion&configure%5BhitsPerPage%5D=500&menu%5Bproducts.name%5D=Spatial%20Gene%20Expression)
#
# ## Loupe broswer
# Please download:
# * [Loupe browser installation](https://support.10xgenomics.com/single-cell-gene-expression/software/downloads/latest)
# * [Example of Loupe browser file (mouse brain)](https://cf.10xgenomics.com/samples/spatial-exp/1.1.0/V1_Mouse_Brain_Sagittal_Posterior/V1_Mouse_Brain_Sagittal_Posterior_cloupe.cloupe)

# %% [markdown]
# ![image.png](attachment:1d90537a-34bc-4b57-8c09-05e717f6566a.png)

# %% [markdown]
# # R: Seurat

# %% [markdown]
# Tutorials:
# * [Analysis of single-cell (non-spatial) data with Seurat](https://satijalab.org/seurat/articles/pbmc3k_tutorial.html)
# * [Analysis of Visium and Slide-seq data with Seurat](https://satijalab.org/seurat/archive/v3.2/spatial_vignette.html)

# %% [markdown]
# # Python: Squidpy + Scanpy + Anndata

# %% [markdown]
# Tutorials:
# * [Best practices for single-cell analysis (non-spatial)](https://www.embopress.org/doi/full/10.15252/msb.20188746)
# * [Analysis of single-cell (non-spatial) with Scanpy and Anndata](https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html)
# * Many tutorials and examples on spatial data analysis]()

# %% [markdown]
# ### Visium
# * loading visium data ([mouse brain from Cell2location](https://cell2location.cog.sanger.ac.uk/tutorial/mouse_brain_visium_wo_cloupe_data.zip))
# * [plots from python](https://scanpy-tutorials.readthedocs.io/en/latest/spatial/basic-analysis.html)
# * [visulization with napari with the image in the background](https://squidpy.readthedocs.io/en/latest/external_tutorials/tutorial_napari.html)
# ** lasso tool
# ** annotating and getting things back
# * clustering of spots (SpatialDE2)
# * [using squipy, apply a resnet to spots](https://squidpy.readthedocs.io/en/latest/external_tutorials/tutorial_tf.html?highlight=resnet)
# * compare the clustering methods (SpatialDE2 vs Leiden vs...)
# * MEFISTO
#
# #### optional if time permits
# * [deconvolution (cell2location)](https://cell2location.readthedocs.io/en/latest/notebooks/cell2location_short_demo.html)
# * clustering of cell types (deconvoluted spots) (SpatialDE2)
#
# ### MERFISH
# https://github.com/spacetx-spacejam/data
# [segmented MERFISH data](https://s3.amazonaws.com/starfish.data.spacetx/spacejam2/MERFISH_Allen_VISp/fixed_1001844875.csv)
#
# [MERFISH spots (LARGE file)](https://s3.amazonaws.com/starfish.data.spacetx/spacejam2/MERFISH_Allen_VISp/Allen_MERFISH_spots_with_anatomy.csv)
#
# [MERFISH brain region annotations](https://github.com/spacetx-spacejam/data/blob/master/annotations/Allen_MERFISH_Layers.geojson)
#
# * loading
# * plots with python
# * plots wiht napari
# * plots of segmentation wiht napari
# * accumualte features and plot masks colored by feature
# * clustering of spots and of cells
# * spatialde spots + cells
# * MEFISTO
#
# #### optional: IMC
